# %%
# importing modules
import numpy as np
import pandas as pd
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt

from scipy import stats
from scipy import optimize
from scipy.optimize import curve_fit
from scipy import fftpack
from scipy.integrate import cumulative_trapezoid

# %%
task1_06nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_0.6nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_06nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_0.6nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_08nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_0.8nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_08nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_0.8nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_1nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_1nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_1nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_1nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_20nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_20nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_20nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_20nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_50nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_50nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_50nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_50nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_100nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_100nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_100nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_100nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_150nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_150nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_150nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_150nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_208nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_208nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_208nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_208nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_350nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_350nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_350nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_350nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_500nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_500nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_500nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_500nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)

task1_pre_data1 = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_pre_data1.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_pre_spec1 = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_pre_spectrum1.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0)
task1_pre_data2 = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_pre_data2.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task1_pre_spec2 = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task1_pre_spectrum2.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0)

# %%
task1_06nF_freq = np.array(task1_06nF_spec['Frequency'])*1000
task1_06nF_amp = np.array(task1_06nF_spec['Channel B'])
task1_08nF_freq = np.array(task1_08nF_spec['Frequency'])*1000
task1_08nF_amp = np.array(task1_08nF_spec['Channel B'])
task1_1nF_freq = np.array(task1_1nF_spec['Frequency'])*1000
task1_1nF_amp = np.array(task1_1nF_spec['Channel B'])
task1_20nF_freq = np.array(task1_20nF_spec['Frequency'])*1000
task1_20nF_amp = np.array(task1_20nF_spec['Channel B'])
task1_50nF_freq = np.array(task1_50nF_spec['Frequency'])*1000
task1_50nF_amp = np.array(task1_50nF_spec['Channel B'])
task1_100nF_freq = np.array(task1_100nF_spec['Frequency'])*1000
task1_100nF_amp = np.array(task1_100nF_spec['Channel B'])
task1_150nF_freq = np.array(task1_150nF_spec['Frequency'])*1000
task1_150nF_amp = np.array(task1_150nF_spec['Channel B'])
task1_208nF_freq = np.array(task1_208nF_spec['Frequency'])*1000
task1_208nF_amp = np.array(task1_208nF_spec['Channel B'])
task1_350nF_freq = np.array(task1_350nF_spec['Frequency'])*1000
task1_350nF_amp = np.array(task1_350nF_spec['Channel B'])
task1_500nF_freq = np.array(task1_500nF_spec['Frequency'])*1000
task1_500nF_amp = np.array(task1_500nF_spec['Channel B'])

# %% [markdown]
# # Task 1 pre

# %%
L = 0.3 # H

# %%
task1_pre_freq1 = np.array(task1_pre_spec1['Frequency'].astype(float))*1000
task1_pre_amp1 = np.array(task1_pre_spec1['Channel B'].astype(float))
task1_pre_freq2 = np.array(task1_pre_spec2['Frequency'].astype(float))*1000
task1_pre_amp2 = np.array(task1_pre_spec2['Channel B'].astype(float))

# %%
task1_pre_peak_index1, task1_pre_peak_heights1 = sp.signal.find_peaks(task1_pre_amp1, height = -10, distance = 10)

task1_pre_peak_index2, task1_pre_peak_heights2 = sp.signal.find_peaks(task1_pre_amp2, height = -10, distance = 10)

task1_pre_freq1[task1_pre_peak_index1[0]], task1_pre_freq2[task1_pre_peak_index2[0]]
# Out:
# (4768.37158, 4673.00415)

# %%
C_pretask = 1/(L * task1_pre_freq1[task1_pre_peak_index2[0]]**2 * 4 * np.pi**2)
C_pretask
# Out:
# 3.8665771058379405e-09

# %%
plt.plot(task1_pre_freq1, task1_pre_amp1)
plt.plot(task1_pre_freq2, task1_pre_amp2)
plt.xlim(0, 5000)
# Out:
# (0.0, 5000.0)

# %% [markdown]
# # Task 1

# %%
task1_06nF_time = np.array(task1_06nF_data['Time'])/1000
task1_06nF_volt = np.array(task1_06nF_data['Channel B'])

# %%
plt.plot(task1_06nF_time, task1_06nF_volt)

# %%
plt.plot(task1_06nF_freq/1000, task1_06nF_amp, label = '0.6 nF')
plt.plot(task1_08nF_freq/1000, task1_08nF_amp, label = '0.8 nF')
plt.plot(task1_1nF_freq/1000, task1_1nF_amp, label = '1 nF')
plt.plot(task1_20nF_freq/1000, task1_20nF_amp, label = '20 nF')
plt.plot(task1_50nF_freq/1000, task1_50nF_amp, label = '50 nF')
plt.plot(task1_100nF_freq/1000, task1_100nF_amp, label = '100 nF')
plt.plot(task1_150nF_freq/1000, task1_150nF_amp, label = '150 nF')
plt.plot(task1_208nF_freq/1000, task1_208nF_amp, label = '208 nF')
plt.plot(task1_350nF_freq/1000, task1_350nF_amp, label = '350 nF')
plt.plot(task1_500nF_freq/1000, task1_500nF_amp, label = '500 nF')
plt.xlim(0,35)
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Amplitude (dBu)')
plt.savefig('task1_spectra.png')

# %%
task1_C = np.array([0.6, 0.8, 1, 20, 50, 100, 150, 208, 350, 500]) * 10**(-9)
task1_f1 = np.zeros(10)
task1_f2 = np.zeros(10)

# %%
task1_06nF_peak_index, task1_06nF_peak_heights = sp.signal.find_peaks(task1_06nF_amp, height = -40, distance = 10)
task1_f1[0], task1_f2[0] = task1_06nF_freq[task1_06nF_peak_index[0]], task1_06nF_freq[task1_06nF_peak_index[1]]
task1_f1[0], task1_f2[0]
# Out:
# (4768.37158, 30326.84326)

# %%
task1_08nF_peak_index, task1_08nF_peak_heights = sp.signal.find_peaks(task1_08nF_amp, height = -40, distance = 10)
task1_f1[1], task1_f2[1] = task1_08nF_freq[task1_08nF_peak_index[0]], task1_08nF_freq[task1_08nF_peak_index[1]]
task1_f1[1], task1_f2[1]
# Out:
# (4768.37158, 27561.18774)

# %%
task1_1nF_peak_index, task1_1nF_peak_heights = sp.signal.find_peaks(task1_1nF_amp, height = -35, distance = 10)
task1_f1[2], task1_f2[2] = task1_1nF_freq[task1_1nF_peak_index[0]], task1_1nF_freq[task1_1nF_peak_index[1]]
task1_f1[2], task1_f2[2]
# Out:
# (4768.37158, 26130.67627)

# %%
task1_20nF_peak_index, task1_20nF_peak_heights = sp.signal.find_peaks(task1_20nF_amp, height = -30, distance = 10)
task1_f1[3], task1_f2[3] = task1_20nF_freq[task1_20nF_peak_index[0]], task1_20nF_freq[task1_20nF_peak_index[1]]
task1_f1[3], task1_f2[3]
# Out:
# (4768.37158, 8392.33398)

# %%
task1_50nF_peak_index, task1_50nF_peak_heights = sp.signal.find_peaks(task1_50nF_amp, height = -30, distance = 10)
task1_f1[4], task1_f2[4] = task1_50nF_freq[task1_50nF_peak_index[0]], task1_50nF_freq[task1_50nF_peak_index[1]]
task1_f1[4], task1_f2[4]
# Out:
# (4768.37158, 6484.98535)

# %%
task1_100nF_peak_index, task1_100nF_peak_heights = sp.signal.find_peaks(task1_100nF_amp, height = -30, distance = 5)
task1_f1[5], task1_f2[5] = task1_100nF_freq[task1_100nF_peak_index[0]], task1_100nF_freq[task1_100nF_peak_index[1]]
task1_f1[5], task1_f2[5]
# Out:
# (4768.37158, 5626.67847)

# %%
task1_150nF_peak_index, task1_150nF_peak_heights = sp.signal.find_peaks(task1_150nF_amp, height = -30, distance = 5)
task1_f1[6], task1_f2[6] = task1_150nF_freq[task1_150nF_peak_index[0]], task1_150nF_freq[task1_150nF_peak_index[1]]
task1_f1[6], task1_f2[6]
# Out:
# (4768.37158, 5340.57617)

# %%
task1_208nF_peak_index, task1_208nF_peak_heights = sp.signal.find_peaks(task1_208nF_amp, height = -30, distance = 2)
task1_f1[7], task1_f2[7] = task1_208nF_freq[task1_208nF_peak_index[0]], task1_208nF_freq[task1_208nF_peak_index[1]]
task1_f1[7], task1_f2[7]
# Out:
# (4768.37158, 5149.84131)

# %%
task1_350nF_peak_index, task1_350nF_peak_heights = sp.signal.find_peaks(task1_350nF_amp, height = -30, distance = 2)
task1_f1[8], task1_f2[8] = task1_350nF_freq[task1_350nF_peak_index[0]], task1_350nF_freq[task1_350nF_peak_index[1]]
task1_f1[8], task1_f2[8]
# Out:
# (4673.00415, 5054.47388)

# %%
task1_500nF_peak_index, task1_500nF_peak_heights = sp.signal.find_peaks(task1_500nF_amp, height = -30, distance = 1)
task1_f1[9], task1_f2[9] = task1_500nF_freq[task1_500nF_peak_index[0]], task1_500nF_freq[task1_500nF_peak_index[0]]
task1_f1[9], task1_f2[9]
# Out:
# (4768.37158, 4768.37158)

# %%
task1_ks = np.abs(((2*np.pi*task1_f1)**2 - (2*np.pi*task1_f2)**2)/((2*np.pi*task1_f1)**2 + (2*np.pi*task1_f2)**2))
task1_ks
# Out:
# array([0.95174863, 0.94187466, 0.93554708, 0.51190941, 0.29814711,
#        0.1640194 , 0.11284599, 0.07680945, 0.07831094, 0.        ])

# %%
def task1_fit(Ck, C):
  return C/(C + Ck)

# %%
popt1, pcov1 = curve_fit(task1_fit, task1_C, task1_ks, p0 = [10**(-6)])
Ck_smooth = np.linspace(task1_C[0], task1_C[-1], 1000)
popt1, np.sqrt(pcov1[0][0])
# Out:
# (array([2.02119977e-08]), 1.0347616418954731e-09)

# %%
task1_C, task1_f1, task1_f2, task1_ks
# Out:
# (array([6.00e-10, 8.00e-10, 1.00e-09, 2.00e-08, 5.00e-08, 1.00e-07,
#         1.50e-07, 2.08e-07, 3.50e-07, 5.00e-07]),
#  array([4768.37158, 4768.37158, 4768.37158, 4768.37158, 4768.37158,
#         4768.37158, 4768.37158, 4768.37158, 4673.00415, 4768.37158]),
#  array([30326.84326, 27561.18774, 26130.67627,  8392.33398,  6484.98535,
#          5626.67847,  5340.57617,  5149.84131,  5054.47388,  4768.37158]),
#  array([0.95174863, 0.94187466, 0.93554708, 0.51190941, 0.29814711,
#         0.1640194 , 0.11284599, 0.07680945, 0.07831094, 0.        ]))

# %%
plt.scatter(task1_C*10**9, task1_ks, label = 'data')
plt.plot(Ck_smooth*10**9, task1_fit(Ck_smooth, popt1[0]), label = 'fit', c = 'r', zorder = -1)
plt.legend()
plt.xlabel(r'Coupling capacitance $C_k$ (nF)')
plt.ylabel('Coupling factor k (unitless)')
plt.savefig('task1_kplot.png')

# %% [markdown]
# # Task 2

# %%
task2_5nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_5nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_5nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_5nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_15nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_15nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_15nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_15nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_40nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_40nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_40nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_40nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_80nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_80nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_80nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_80nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
#task2_200nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_200nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_200nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_200nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
#task2_400nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_400nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_400nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_400nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
#task2_700nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_700nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_700nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_700nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
#task2_1000nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_1000nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_1000nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_1000nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
#task2_1700nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_1700nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_1700nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_1700nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
#task2_3000nF_data = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_3000nF_data.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)
task2_3000nF_spec = pd.read_csv('https://raw.githubusercontent.com/kundiilona/GP2/main/task2_3000nF_spec.csv', delimiter = ',', decimal = '.').drop(axis=0, index=0).astype(float)

# %%
task2_5nF_freq = np.array(task2_5nF_spec['Frequency'])*1000
task2_5nF_amp = np.array(task2_5nF_spec['Channel B'])
task2_15nF_freq = np.array(task2_15nF_spec['Frequency'])*1000
task2_15nF_amp = np.array(task2_15nF_spec['Channel B'])
task2_40nF_freq = np.array(task2_40nF_spec['Frequency'])*1000
task2_40nF_amp = np.array(task2_40nF_spec['Channel B'])
task2_80nF_freq = np.array(task2_80nF_spec['Frequency'])*1000
task2_80nF_amp = np.array(task2_80nF_spec['Channel B'])
task2_200nF_freq = np.array(task2_200nF_spec['Frequency'])*1000
task2_200nF_amp = np.array(task2_200nF_spec['Channel B'])
task2_400nF_freq = np.array(task2_400nF_spec['Frequency'])*1000
task2_400nF_amp = np.array(task2_400nF_spec['Channel B'])
task2_700nF_freq = np.array(task2_700nF_spec['Frequency'])*1000
task2_700nF_amp = np.array(task2_700nF_spec['Channel B'])
task2_1000nF_freq = np.array(task2_1000nF_spec['Frequency'])*1000
task2_1000nF_amp = np.array(task2_1000nF_spec['Channel B'])
task2_1700nF_freq = np.array(task2_1700nF_spec['Frequency'])*1000
task2_1700nF_amp = np.array(task2_1700nF_spec['Channel B'])
task2_3000nF_freq = np.array(task2_3000nF_spec['Frequency'])*1000
task2_3000nF_amp = np.array(task2_3000nF_spec['Channel B'])

# %%
plt.plot(task2_5nF_freq/1000, task2_5nF_amp, label = '5 nF')
plt.plot(task2_15nF_freq/1000, task2_15nF_amp, label = '15 nF')
plt.plot(task2_40nF_freq/1000, task2_40nF_amp, label = '40 nF')
plt.plot(task2_80nF_freq/1000, task2_80nF_amp, label = '80 nF')
plt.plot(task2_200nF_freq/1000, task2_200nF_amp, label = '200 nF')
plt.plot(task2_400nF_freq/1000, task2_400nF_amp, label = '400 nF')
plt.plot(task2_700nF_freq/1000, task2_700nF_amp, label = '700 nF')
plt.plot(task2_1000nF_freq/1000, task2_1000nF_amp, label = '1000 nF')
plt.plot(task2_1700nF_freq/1000, task2_1700nF_amp, label = '1700 nF')
plt.plot(task2_3000nF_freq/1000, task2_3000nF_amp, label = '3000 nF')
plt.xlim(0,8)
#plt.axvline(task2_f2[0]/1000)
plt.legend()
plt.xlabel('Frequency (kHz)')
plt.ylabel('Amplitude (dBu)')
plt.savefig('task2_spectra.png')

# %%
task2_C = np.array([5, 15, 40, 80, 200, 400, 700, 1000, 1700, 3000]) * 10**(-9)
task2_f1 = np.zeros(10)
task2_f2 = np.zeros(10)

# %%
task2_5nF_peak_index, task2_5nF_peak_heights = sp.signal.find_peaks(task2_5nF_amp, height = -40, distance = 3)
task2_f1[0], task2_f2[0] = task2_5nF_freq[task2_5nF_peak_index[0]], task2_5nF_freq[task2_5nF_peak_index[1]]
task2_f1[0], task2_f2[0]
# Out:
# (3910.0647, 4768.37158)

# %%
task2_15nF_peak_index, task2_15nF_peak_heights = sp.signal.find_peaks(task2_15nF_amp, height = -40, distance = 3)
task2_f1[1], task2_f2[1] = task2_15nF_freq[task2_15nF_peak_index[0]], task2_15nF_freq[task2_15nF_peak_index[1]]
task2_f1[1], task2_f2[1]
# Out:
# (3051.7578099999996, 4768.37158)

# %%
task2_40nF_peak_index, task2_40nF_peak_heights = sp.signal.find_peaks(task2_40nF_amp, height = -40, distance = 3)
task2_f1[2], task2_f2[2] = task2_40nF_freq[task2_40nF_peak_index[0]], task2_40nF_freq[task2_40nF_peak_index[1]]
task2_f1[2], task2_f2[2]
# Out:
# (2193.45093, 4768.37158)

# %%
task2_80nF_peak_index, task2_80nF_peak_heights = sp.signal.find_peaks(task2_80nF_amp, height = -40, distance = 10)
task2_f1[3], task2_f2[3] = task2_80nF_freq[task2_80nF_peak_index[0]], task2_80nF_freq[task2_80nF_peak_index[1]]
task2_f1[3], task2_f2[3]
# Out:
# (1621.24634, 4768.37158)

# %%
task2_200nF_peak_index, task2_200nF_peak_heights = sp.signal.find_peaks(task2_200nF_amp, height = -40, distance = 10)
task2_f1[4], task2_f2[4] = task2_200nF_freq[task2_200nF_peak_index[0]], task2_200nF_freq[task2_200nF_peak_index[1]]
task2_f1[4], task2_f2[4]
# Out:
# (1049.04175, 4768.37158)

# %%
task2_400nF_peak_index, task2_400nF_peak_heights = sp.signal.find_peaks(task2_400nF_amp, height = -40, distance = 10)
task2_f1[5], task2_f2[5] = task2_400nF_freq[task2_400nF_peak_index[0]], task2_400nF_freq[task2_400nF_peak_index[1]]
task2_f1[5], task2_f2[5]
# Out:
# (762.93945, 4768.37158)

# %%
task2_700nF_peak_index, task2_700nF_peak_heights = sp.signal.find_peaks(task2_700nF_amp, height = -40, distance = 10)
task2_f1[6], task2_f2[6] = task2_700nF_freq[task2_700nF_peak_index[0]], task2_700nF_freq[task2_700nF_peak_index[1]]
task2_f1[6], task2_f2[6]
# Out:
# (572.20459, 4768.37158)

# %%
task2_1000nF_peak_index, task2_1000nF_peak_heights = sp.signal.find_peaks(task2_1000nF_amp, height = -40, distance = 10)
task2_f1[7], task2_f2[7] = task2_1000nF_freq[task2_1000nF_peak_index[0]], task2_1000nF_freq[task2_1000nF_peak_index[1]]
task2_f1[7], task2_f2[7]
# Out:
# (476.83716, 4768.37158)

# %%
task2_1700nF_peak_index, task2_1700nF_peak_heights = sp.signal.find_peaks(task2_1700nF_amp, height = -40, distance = 10)
task2_f1[8], task2_f2[8] = task2_1700nF_freq[task2_1700nF_peak_index[0]], task2_1700nF_freq[task2_1700nF_peak_index[1]]
task2_f1[8], task2_f2[8]
# Out:
# (381.46973, 4768.37158)

# %%
task2_3000nF_peak_index, task2_3000nF_peak_heights = sp.signal.find_peaks(task2_3000nF_amp, height = -75, distance = 10)
task2_f1[9], task2_f2[9] = task2_3000nF_freq[task2_3000nF_peak_index[0]], task2_3000nF_freq[task2_3000nF_peak_index[1]]
task2_f1[9], task2_f2[9]
# Out:
# (274.18136999999996, 4744.52972)

# %%
task2_ks = (task2_f2**2 - task2_f1**2)/((task2_f2**2 + task2_f1**2))

# %%
def task2_fit(Ck, C):
  return Ck / (C + Ck)

# %%
popt2, pcov2 = curve_fit(task2_fit, task2_C, task2_ks, p0 = [10**(-9)])
Ck_smooth2 = np.linspace(5, 3000, 1000)*10**(-9)
popt2, np.sqrt(pcov2[0][0])
# Out:
# (array([2.09605753e-08]), 1.2068585674228524e-10)

# %%
task2_C, task2_f1, task2_f2, task2_ks
# Out:
# (array([5.0e-09, 1.5e-08, 4.0e-08, 8.0e-08, 2.0e-07, 4.0e-07, 7.0e-07,
#         1.0e-06, 1.7e-06, 3.0e-06]),
#  array([3910.0647 , 3051.75781, 2193.45093, 1621.24634, 1049.04175,
#          762.93945,  572.20459,  476.83716,  381.46973,  274.18137]),
#  array([4768.37158, 4768.37158, 4768.37158, 4768.37158, 4768.37158,
#         4768.37158, 4768.37158, 4768.37158, 4768.37158, 4744.52972]),
#  array([0.19588615, 0.41884223, 0.6507098 , 0.79275726, 0.90766883,
#         0.950078  , 0.97160883, 0.98019802, 0.9872814 , 0.99334311]))

# %%
plt.scatter(task2_C*10**9, task2_ks, label = 'data')
plt.plot(Ck_smooth2*10**9, task2_fit(Ck_smooth2, popt2[0]), label = 'fit', c = 'r', zorder = -2)
plt.legend()
plt.xlabel(r'Coupling capacitance $C_k$ (nF)')
plt.ylabel('Coupling factor k (unitless)')
plt.savefig('task2_kplot.png')
